# %%
#Задание 1. Даны 2 переменных, в которых хранятся строки произвольной длины: phrase_1 и phrase_2.
#Напишите код, который проверяет какая из этих строк длиннее.

phrase_1 = input('Введите значение переменной phrase_1: ')
phrase_2 = input('Введите значение переменной phrase_2: ')
if len(phrase_1) > len(phrase_2):
    print('Фраза 1 длиннее Фразы 2')
elif len(phrase_1) < len(phrase_2):
    print('Фраза 2 длиннее Фразы 1')
else:
    print('Фразы одинаковой длины')
# Out:
# Введите значение переменной phrase_1: аргшпынуш
# Введите значение переменной phrase_2: очяРВфлнуафшг
# Фраза 2 длиннее Фразы 1

# %%
#Задание 2. Дана переменная, в которой хранится четырехзначное число (год).
#Необходимо написать программу, которая выведет, является ли данный год високосным или обычным.

year = int(input('Введите год: '))
if (year%4 == 0 and year%100 != 0) or year%400 == 0:
    print('Введенный год - високосный')
else:
    print('Введенный год - обычный')
# Out:
# Введите год: 2032
# Введенный год - високосный

# %%
#Задание 3. Необходимо написать программу, которая будет запрашивать у пользователя
#месяц и дату рождения и выводить соответствующий знак зодиака.

month = input('Введите месяц: ')
day = int(input('Введите день: '))
if (month == 'январь' and 32 > day >= 20) or (month == 'февраль' and day < 20): 
    print('Ваш знак зодиака: Водолей')
elif (month == 'февраль' and 30 > day >= 20) or (month == 'март' and day < 21):
    print('Ваш знак зодиака: Рыбы')
elif (month == 'март' and 32 > day >= 21) or (month == 'апрель' and day < 21):
    print('Ваш знак зодиака: Овен')
elif (month == 'апрель' and 31 > day >= 21) or (month == 'май' and day < 21):
    print('Ваш знак зодиака: Телец')
elif (month == 'май' and 32 > day >= 21) or (month == 'июнь' and day < 21):
    print('Ваш знак зодиака: Близнецы')
elif (month == 'июнь' and 31 > day >= 21) or (month == 'июль' and day < 23):
    print('Ваш знак зодиака: Рак')
elif (month == 'июль' and 32 > day >= 23) or (month == 'август' and day < 23):
    print('Ваш знак зодиака: Лев')
elif (month == 'август' and 32 > day >= 23) or (month == 'сентябрь' and day < 23):
    print('Ваш знак зодиака: Дева')
elif (month == 'сентябрь' and 31 > day >= 23) or (month == 'октябрь' and day < 23):
    print('Ваш знак зодиака: Весы')
elif (month == 'октябрь' and 32 > day >= 23) or (month=='ноябрь' and day < 23):
    print('Ваш знак зодиака: Скорпион')
elif (month == 'ноябрь' and 31 > day >= 23) or (month == 'декабрь' and day < 22):
    print('Ваш знак зодиака: Стрелец')
elif (month == 'декабрь' and 32 > day >= 22) or (month == 'январь' and day < 20):
    print('Ваш знак зодиака: Козерог')
else:
    print('значение даты или месяца было введено с ошибкой. По некорректным данным определить знак зодиака невозможно')
# Out:
# Введите месяц: декабрь
# Введите день: 22
# Ваш знак зодиака: Козерог

# %%
#Задание 4. Вам нужно написать программу для подбора упаковок по размерам товара.
#Размеры (ширина, длина, высота) хранятся в переменных (в сантиметрах).
#Используйте следующие правила:
#если каждое из трех измерений менее 15 сантиметров, то выведите на экран "Коробка №1";
#если хотя бы одно из измерений больше 15 сантиметров, но менее 50 сантиметров, то выводите "Коробка №2";
#если длина товара больше 2 метров, то выводите "Упаковка для лыж";
#во всех остальных случаях выводите "Стандартная коробка №3".

length = int(input('Введите длину короба(см) : '))
width = int(input('Введите ширину короба(см) : '))
height = int(input('Введите высоту короба(см): '))
if length > 200:
    print('Упаковка для лыж')
elif 0 < width < 15 and 0 < length < 15 and 0 < height < 15:
    print('Коробка №1')
elif 50 > width > 15 or 50 > length > 15 or 50 > height > 15:
    print('Коробка №2')
else:
    print('Стандартная коробка №3')
# Out:
# Введите длину короба(см): 14
# Введите ширину короба(см): 12
# Введите высоту короба(см): 56
# Стандартная коробка №3

# %%
#Задание 5. Дана переменная, в которой хранится шестизначное число (номер проездного билета).
#Напишите программу, которая будет определять, является ли данный билет "счастливым".
#Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера.

ticket_number = int(input('Введите шестизначное число: '))
if len(str(ticket_number))!= 6:
    print('вы ввели не шестизначное число. расчет счастливого номера производиться не будет')
else:
    num1 = ticket_number // 100000
    num2 = ticket_number // 10000 - (ticket_number // 100000) * 10
    num3 = ticket_number // 1000 - (ticket_number // 10000) * 10
    num4 = ticket_number // 100 - (ticket_number // 1000) * 10
    num5 = ticket_number // 10 - (ticket_number // 100) * 10
    num6 = ticket_number % 10
    if num1 + num2 + num3 == num4 + num5 + num6:
        print('У вас счастливый билет!')
    else:
        print('У вас несчастливый билет')
# Out:
# Введите шестизначное число: 843780
# У вас счастливый билет!

# %%
#Задание 6. Напишите программу, которая сможет вычислять площади трех фигур (круг, треугольник и прямоугольник).
#Тип фигуры запрашиваем через пользовательский ввод, после чего делаем запрос характеристик фигуры:
#    если пользователь выбрал круг, запрашиваем его радиус,
#    если треугольник – длины трех его сторон,
#    если прямоугольник – длины двух его сторон.

figure = int(input('Введите код фигуры,площадь которой хотите вычислить: 1 - круг, 2 - треугольник, 3 - прямоугольник: '))
if figure != 1 and figure != 2 and figure != 3:
    print('Вы ввели несуществующий код. Расчет площади фигуры производиться не будет.')
else:
    if figure == 1:
        R = int(input('Введите радиус круга: '))
        print('Площадь круга составляет: ', 3.14 * R ** 2)
    elif figure == 2:
        a = int(input('Введите длину стороны A: '))
        b = int(input('Введите длину стороны B: '))
        c = int(input('Введите длину стороны C: '))
        p = (a + b + c) / 2 #полупериметр треугольника
        print('Площадь треугольника составляет: ', (p * (p-a) * (p-b) * (p-c)) ** 1/2)
    elif figure == 3:
        a = int(input('Введите длину стороны A: '))
        b = int(input('Введите длину стороны B: '))
        print('Площадь Прямоугольника составляет: ', a * b)
# Out:
# Введите код фигуры,площадь которой хотите вычислить: 1 - круг, 2 - треугольник, 3 - прямоугольник: 3
# Введите длину стороны A: 7
# Введите длину стороны B: 5
# Площадь Прямоугольника составляет:  35
